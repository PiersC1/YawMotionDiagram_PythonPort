# %%
from pacejkaNN import load_model

model = load_model("./NN_model/norm_params.json", "./NN_model/R20_tire_model.pth")

# %%
model.compute_forces(-1000, 12)
# Out:
# (-2336.2725871732455, 32.135737436550265)
